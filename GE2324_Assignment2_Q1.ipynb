# %%
import numpy as np

# %%
def dist(row, centroid):
    return np.round(np.linalg.norm(np.array(row)-np.array(centroid)),1)


def k_means_clustering(data, k, centroids, max_iterations=100, tolerance=1e-4, log=True):



    for _ in range(max_iterations):

        if log: 
            print(f"ITERATION {_+1}")
        
        clusters = [[] for _ in range(k)]
        for i,point in enumerate(data):
            if log: 
                print(f"{i+1}:", end=' ')
            distances = [dist(point, centroid) for centroid in centroids]
            if log: 
                print(f"L2 distances: {distances}", end='--->')
            closest_centroid = np.argmin(distances)
            clusters[closest_centroid].append([i+1,point])
            if log: 
                print(f"Cluster {closest_centroid+1}")
        

        new_centroids = []
        for i in range(k):
            points_for_cluster = [lst[1] for lst in clusters[i]]
            new_centroid = np.round(np.mean(points_for_cluster, axis=0),1)
            new_centroids.append(new_centroid)


        if np.sum(np.abs(np.array(new_centroids) - np.array(centroids))) < tolerance:
            break

        centroids = new_centroids
        
        if log: 
            print()
        
    return clusters, centroids

def Q1(centroids):
    print(f"Initial {centroids1=}\n")
    clusters, centroids = k_means_clustering(data, len(centroids), centroids)
    print("\nClusters:")
    for i, cluster in enumerate(clusters):
        print(f"Colors in Cluster {i+1}:")
        for lst in cluster:
            print(f'{lst[0]}')
        print("")

    print("Centroids:")
    for centroid in centroids:
        print(centroid)

def difference(centroids1, centroids2):
    clusters1, centroids1 = k_means_clustering(data, len(centroids1), centroids1, log=False)
    clusters2, centroids2 = k_means_clustering(data, len(centroids2), centroids2, log=False)
    print(f'Colors that are in different clusters after 2 simulations:')
    
    lst1, lst2 = [], []
    for cluster1, cluster2 in zip(clusters1, clusters2):

        set1, set2 = set(), set()

        for lst in cluster1:
            set1.add(lst[0])
        for lst in cluster2:
            set2.add(lst[0])
        lst1.append(set1)
        lst2.append(set2)
    
    lst1.sort(key=len)
    lst2.sort(key=len)
    
    differences = []
    
    for set1, set2 in zip(lst1,lst2):        
        differences += list(set1^set2)
    
    print(set(differences))

# %%
data = [[172, 204, 210],
        [167, 119, 70],
        [247, 231, 184],
        [222, 181, 126],
        [98, 109, 128],
        [85, 74, 71],
        [136, 122, 103],
        [116, 80, 58],
        [207, 135, 67],
        [23, 25, 23],
        [132, 156, 179],
        [147, 101, 64],
        [125, 101, 75],
        [162, 139, 108],
        [52, 51, 50],
        [187, 161, 116]
       ]
centroids1 = [data[6], data[8], data[10]]
centroids2 = [data[0], data[1], data[2]]

# %%
Q1(centroids1)
# Out:
# Initial centroids1=[[136, 122, 103], [207, 135, 67], [132, 156, 179]]
#
# ITERATION 1
# 1: L2 distances: [139.5, 162.6, 69.7]--->Cluster 3
# 2: L2 distances: [45.4, 43.2, 120.3]--->Cluster 2
# 3: L2 distances: [175.4, 156.5, 137.4]--->Cluster 3
# 4: L2 distances: [106.8, 76.3, 107.4]--->Cluster 2
# 5: L2 distances: [47.3, 127.6, 77.2]--->Cluster 1
# 6: L2 distances: [77.0, 136.5, 143.5]--->Cluster 1
# 7: L2 distances: [0.0, 80.7, 83.4]--->Cluster 1
# 8: L2 distances: [64.7, 106.7, 143.8]--->Cluster 1
# 9: L2 distances: [80.7, 0.0, 136.4]--->Cluster 2
# 10: L2 distances: [169.1, 218.8, 231.0]--->Cluster 1
# 11: L2 distances: [83.4, 136.4, 0.0]--->Cluster 3
# 12: L2 distances: [45.6, 69.0, 128.4]--->Cluster 1
# 13: L2 distances: [36.7, 89.1, 117.9]--->Cluster 1
# 14: L2 distances: [31.5, 61.0, 78.9]--->Cluster 1
# 15: L2 distances: [122.1, 177.1, 184.6]--->Cluster 1
# 16: L2 distances: [65.5, 59.0, 83.8]--->Cluster 2
#
# ITERATION 2
# 1: L2 distances: [189.1, 129.9, 23.4]--->Cluster 3
# 2: L2 distances: [69.2, 48.4, 144.9]--->Cluster 2
# 3: L2 distances: [228.2, 131.5, 72.2]--->Cluster 3
# 4: L2 distances: [157.2, 51.8, 77.1]--->Cluster 2
# 5: L2 distances: [56.5, 110.8, 138.0]--->Cluster 1
# 6: L2 distances: [25.4, 135.9, 198.2]--->Cluster 1
# 7: L2 distances: [52.9, 66.1, 125.1]--->Cluster 1
# 8: L2 distances: [22.7, 111.7, 189.6]--->Cluster 1
# 9: L2 distances: [112.3, 33.1, 140.6]--->Cluster 2
# 10: L2 distances: [116.5, 224.5, 289.2]--->Cluster 1
# 11: L2 distances: [126.1, 105.9, 67.1]--->Cluster 3
# 12: L2 distances: [45.3, 75.1, 163.4]--->Cluster 1
# 13: L2 distances: [23.4, 87.8, 161.6]--->Cluster 1
# 14: L2 distances: [82.5, 37.6, 103.6]--->Cluster 2
# 15: L2 distances: [70.0, 179.7, 242.0]--->Cluster 1
# 16: L2 distances: [116.4, 25.9, 83.3]--->Cluster 2
#
# ITERATION 3
# 1: L2 distances: [198.4, 127.3, 23.4]--->Cluster 3
# 2: L2 distances: [78.1, 44.9, 144.9]--->Cluster 2
# 3: L2 distances: [238.4, 133.9, 72.2]--->Cluster 3
# 4: L2 distances: [167.4, 55.3, 77.1]--->Cluster 2
# 5: L2 distances: [62.2, 103.3, 138.0]--->Cluster 1
# 6: L2 distances: [15.6, 129.8, 198.2]--->Cluster 1
# 7: L2 distances: [63.1, 58.9, 125.1]--->Cluster 2
# 8: L2 distances: [22.8, 106.6, 189.6]--->Cluster 1
# 9: L2 distances: [121.1, 37.3, 140.6]--->Cluster 2
# 10: L2 distances: [106.3, 219.0, 289.2]--->Cluster 1
# 11: L2 distances: [134.4, 99.9, 67.1]--->Cluster 3
# 12: L2 distances: [53.0, 70.7, 163.4]--->Cluster 1
# 13: L2 distances: [32.9, 81.9, 161.6]--->Cluster 1
# 14: L2 distances: [92.7, 30.1, 103.6]--->Cluster 2
# 15: L2 distances: [59.8, 173.9, 242.0]--->Cluster 1
# 16: L2 distances: [126.6, 23.4, 83.3]--->Cluster 2
#
# ITERATION 4
# 1: L2 distances: [207.0, 127.6, 23.4]--->Cluster 3
# 2: L2 distances: [85.6, 39.3, 144.9]--->Cluster 2
# 3: L2 distances: [247.5, 139.9, 72.2]--->Cluster 3
# 4: L2 distances: [176.2, 63.0, 77.1]--->Cluster 2
# 5: L2 distances: [69.0, 93.7, 138.0]--->Cluster 1
# 6: L2 distances: [9.0, 120.6, 198.2]--->Cluster 1
# 7: L2 distances: [72.1, 49.1, 125.1]--->Cluster 2
# 8: L2 distances: [25.5, 98.4, 189.6]--->Cluster 1
# 9: L2 distances: [128.4, 41.9, 140.6]--->Cluster 2
# 10: L2 distances: [97.3, 210.4, 289.2]--->Cluster 1
# 11: L2 distances: [142.5, 94.9, 67.1]--->Cluster 3
# 12: L2 distances: [59.7, 63.5, 163.4]--->Cluster 1
# 13: L2 distances: [41.2, 73.1, 161.6]--->Cluster 1
# 14: L2 distances: [101.7, 21.0, 103.6]--->Cluster 2
# 15: L2 distances: [51.0, 164.9, 242.0]--->Cluster 1
# 16: L2 distances: [135.6, 26.3, 83.3]--->Cluster 2
#
# Clusters:
# Colors in Cluster 1:
# 5
# 6
# 8
# 10
# 12
# 13
# 15
#
# Colors in Cluster 2:
# 2
# 4
# 7
# 9
# 14
# 16
#
# Colors in Cluster 3:
# 1
# 3
# 11
#
# Centroids:
# [92.3 77.3 67. ]
# [180.2 142.8  98.3]
# [183.7 197.  191. ]

# %%
Q1(centroids2)
# Out:
# Initial centroids1=[[136, 122, 103], [207, 135, 67], [132, 156, 179]]
#
# ITERATION 1
# 1: L2 distances: [0.0, 163.9, 83.8]--->Cluster 1
# 2: L2 distances: [163.9, 0.0, 178.7]--->Cluster 2
# 3: L2 distances: [83.8, 178.7, 0.0]--->Cluster 3
# 4: L2 distances: [100.4, 100.0, 80.6]--->Cluster 3
# 5: L2 distances: [145.7, 90.7, 200.6]--->Cluster 2
# 6: L2 distances: [209.3, 93.5, 252.3]--->Cluster 2
# 7: L2 distances: [139.5, 45.4, 175.4]--->Cluster 2
# 8: L2 distances: [204.0, 65.3, 236.3]--->Cluster 2
# 9: L2 distances: [162.6, 43.2, 156.5]--->Cluster 2
# 10: L2 distances: [298.7, 178.3, 344.3]--->Cluster 2
# 11: L2 distances: [69.7, 120.3, 137.4]--->Cluster 1
# 12: L2 distances: [180.4, 27.6, 203.2]--->Cluster 2
# 13: L2 distances: [176.2, 46.0, 209.0]--->Cluster 2
# 14: L2 distances: [121.4, 43.2, 146.5]--->Cluster 2
# 15: L2 distances: [251.8, 135.1, 297.3]--->Cluster 2
# 16: L2 distances: [104.5, 65.4, 114.6]--->Cluster 2
#
# ITERATION 2
# 1: L2 distances: [34.9, 173.7, 83.3]--->Cluster 1
# 2: L2 distances: [139.4, 45.8, 139.1]--->Cluster 2
# 3: L2 distances: [108.3, 207.0, 40.3]--->Cluster 3
# 4: L2 distances: [97.9, 134.1, 40.3]--->Cluster 3
# 5: L2 distances: [111.3, 57.7, 169.6]--->Cluster 2
# 6: L2 distances: [176.0, 49.3, 216.4]--->Cluster 2
# 7: L2 distances: [109.5, 34.2, 139.5]--->Cluster 2
# 8: L2 distances: [173.0, 30.6, 198.3]--->Cluster 2
# 9: L2 distances: [146.0, 88.9, 116.4]--->Cluster 2
# 10: L2 distances: [264.7, 139.0, 308.1]--->Cluster 2
# 11: L2 distances: [34.9, 115.2, 116.5]--->Cluster 1
# 12: L2 distances: [152.6, 25.6, 164.2]--->Cluster 2
# 13: L2 distances: [145.8, 2.9, 171.5]--->Cluster 2
# 14: L2 distances: [96.2, 60.5, 109.3]--->Cluster 2
# 15: L2 distances: [218.0, 93.3, 261.5]--->Cluster 2
# 16: L2 distances: [88.0, 93.8, 76.2]--->Cluster 3
#
# ITERATION 3
# 1: L2 distances: [34.9, 181.1, 83.5]--->Cluster 1
# 2: L2 distances: [139.4, 52.7, 114.2]--->Cluster 2
# 3: L2 distances: [108.3, 215.5, 64.5]--->Cluster 3
# 4: L2 distances: [97.9, 142.6, 19.2]--->Cluster 3
# 5: L2 distances: [111.3, 59.4, 146.6]--->Cluster 2
# 6: L2 distances: [176.0, 41.3, 191.3]--->Cluster 2
# 7: L2 distances: [109.5, 42.0, 114.5]--->Cluster 2
# 8: L2 distances: [173.0, 23.2, 173.0]--->Cluster 2
# 9: L2 distances: [146.0, 95.8, 94.3]--->Cluster 3
# 10: L2 distances: [264.7, 130.5, 282.9]--->Cluster 2
# 11: L2 distances: [34.9, 121.3, 100.6]--->Cluster 1
# 12: L2 distances: [152.6, 29.5, 139.0]--->Cluster 2
# 13: L2 distances: [145.8, 7.2, 146.2]--->Cluster 2
# 14: L2 distances: [96.2, 69.0, 84.1]--->Cluster 2
# 15: L2 distances: [218.0, 84.9, 236.3]--->Cluster 2
# 16: L2 distances: [88.0, 102.4, 50.8]--->Cluster 3
#
# ITERATION 4
# 1: L2 distances: [34.9, 185.6, 100.9]--->Cluster 1
# 2: L2 distances: [139.4, 62.2, 92.6]--->Cluster 2
# 3: L2 distances: [108.3, 222.8, 87.1]--->Cluster 3
# 4: L2 distances: [97.9, 151.0, 7.9]--->Cluster 3
# 5: L2 distances: [111.3, 57.2, 136.1]--->Cluster 2
# 6: L2 distances: [176.0, 32.0, 174.5]--->Cluster 2
# 7: L2 distances: [109.5, 47.9, 99.0]--->Cluster 2
# 8: L2 distances: [173.0, 21.4, 153.7]--->Cluster 2
# 9: L2 distances: [146.0, 105.4, 70.7]--->Cluster 3
# 10: L2 distances: [264.7, 122.3, 265.2]--->Cluster 2
# 11: L2 distances: [34.9, 123.8, 102.8]--->Cluster 1
# 12: L2 distances: [152.6, 38.6, 118.4]--->Cluster 2
# 13: L2 distances: [145.8, 16.5, 127.8]--->Cluster 2
# 14: L2 distances: [96.2, 76.7, 67.6]--->Cluster 3
# 15: L2 distances: [218.0, 76.2, 219.2]--->Cluster 2
# 16: L2 distances: [88.0, 110.4, 33.7]--->Cluster 3
#
# ITERATION 5
# 1: L2 distances: [34.9, 193.4, 101.7]--->Cluster 1
# 2: L2 distances: [139.4, 69.5, 80.6]--->Cluster 2
# 3: L2 distances: [108.3, 231.3, 98.1]--->Cluster 3
# 4: L2 distances: [97.9, 159.5, 21.4]--->Cluster 3
# 5: L2 distances: [111.3, 61.3, 123.1]--->Cluster 2
# 6: L2 distances: [176.0, 24.1, 161.0]--->Cluster 2
# 7: L2 distances: [109.5, 56.3, 85.5]--->Cluster 2
# 8: L2 distances: [173.0, 18.4, 140.6]--->Cluster 2
# 9: L2 distances: [146.0, 112.5, 63.4]--->Cluster 3
# 10: L2 distances: [264.7, 113.8, 251.8]--->Cluster 2
# 11: L2 distances: [34.9, 130.7, 94.7]--->Cluster 1
# 12: L2 distances: [152.6, 44.5, 105.8]--->Cluster 2
# 13: L2 distances: [145.8, 24.4, 114.5]--->Cluster 2
# 14: L2 distances: [96.2, 85.2, 54.1]--->Cluster 3
# 15: L2 distances: [218.0, 67.8, 205.8]--->Cluster 2
# 16: L2 distances: [88.0, 118.9, 20.3]--->Cluster 3
#
# Clusters:
# Colors in Cluster 1:
# 1
# 11
#
# Colors in Cluster 2:
# 2
# 5
# 6
# 7
# 8
# 10
# 12
# 13
# 15
#
# Colors in Cluster 3:
# 3
# 4
# 9
# 14
# 16
#
# Centroids:
# [152.  180.  194.5]
# [105.4  86.9  71.3]
# [205.  169.4 120.2]

# %%
difference(centroids1, centroids2)
# Out:
# Colors that are in different clusters after 2 simulations:
# {2, 3, 7}
